# %% [markdown]
# WebScraping Function

# %%
import requests
# These two things are for Pandas, it widens the notebook and lets us display data easily.
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# !pip3 install spotipy
# Out:
# Requirement already satisfied: spotipy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (2.16.0)
# Requirement already satisfied: requests>=2.20.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spotipy) (2.24.0)
# Requirement already satisfied: six>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spotipy) (1.14.0)
# Requirement already satisfied: idna<3,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.20.0->spotipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.20.0->spotipy) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.20.0->spotipy) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.20.0->spotipy) (3.0.4)
# WARNING: You are using pip version 19.2.3, however version 20.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials 
#To access authorised Spotify data
client_id = '693faf0bce4f4fb0aa5fc5d8b3cc0b25'
client_secret = 'c2ab38a172f44774a0cfae1d7734130f'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

#spotify object to access API
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 
#artist will have to provide their own ID that is assigned to them by spotify
#this is because small bands do not often pop up as the first search return so we cannot rely on that
#there are also duplicate names

#not deemed reliable yet
def get_artistID_by_artistName(artistName):
        artist = sp.search(q=artistName, type="artist")
        artistObject = artist['artists']['items']
        artistID = artistObject[0]['id']
        return artistID;
    
def get_genre(artistID):
    #navigate to artist
    artist = sp.artist(artistID)
    #Obtain genre
    genres = artist['genres']
    return genres

    
def get_followers(artistID):
    #navigate to artist
    artist = sp.artist(artistID)
    #Obtain follower count
    followers = int(artist['followers']['total'])
    return followers

# %%
import requests
# !pip3 install lxml
from lxml import html
# Out:
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (4.5.0)
# WARNING: You are using pip version 19.2.3, however version 20.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import re

#Scrape artist about section to get top cities
#parse for top cities
def get_cities(artistID):
    r = requests.get('https://open.spotify.com/artist/{}/about'.format(artistID), timeout=10)
    match = re.search(r'Where People Listen', r.text)
    #get where people listen starting point
    string = r.text[match.start():]
    #split at colon
    strings = string.split(':')
    strings1 = strings[1].split('"')
    cities = strings1[0].split(",")
    #grab second string
    return cities

def get_monthlyListeners(artistID):
    r = requests.get('https://open.spotify.com/artist/{}/about'.format(artistID), timeout=10)
    match = re.search(r'Monthly Listeners', r.text)
    #get monthly listeners starting point
    string = r.text[match.start():]
    #split at colon
    strings = string.split(':')
    strings1 = strings[1].split(',')
    monthlyListeners = strings1[0].split(",")
    #grab second string
    return int(monthlyListeners[0].lstrip())

#get_cities(artistID)
#get_monthlyListeners(artistID)

# %%
# Set Up DataFrame with Band Names
import pandas as pd

#use names from class... THIS PART WILL BE CHANGED!

names = ["Turnstile", "NoMBe", "Shabaka Hutchings", "Hippo Campus", "Sunday Morning Detox", "Joji", "Jungle Giants", "Magic City Hippies", "Sudan Archives"]

df = pd.DataFrame({"band_name": names})

df
# Out:
#               band_name
# 0             Turnstile
# 1                 NoMBe
# 2     Shabaka Hutchings
# 3          Hippo Campus
# 4  Sunday Morning Detox
# 5                  Joji
# 6         Jungle Giants
# 7    Magic City Hippies
# 8        Sudan Archives

# %%
df["id"] = df.band_name.apply(get_artistID_by_artistName)
df["genre"] = df.id.apply(get_genre)
df["top_locales"] = df.id.apply(get_cities)
df["listeners"] = df.id.apply(get_monthlyListeners)
df["followers"] = df.id.apply(get_followers)
pd.set_option("display.max_rows", None, "display.max_columns", None, 'display.max_colwidth', -1)
df
# Out:
#               band_name                      id  \
# 0  Turnstile             2qnpHrOzdmOo1S4ox3j17x
# 1  NoMBe                 5Lhxlge1CR1DrgDAje8Qaw
# 2  Shabaka Hutchings     6ywMpa6AmGJpV5Sbyy58Js
# 3  Hippo Campus          1btWGBz4Uu1HozTwb2Lm8A
# 4  Sunday Morning Detox  0ebYhazPi5731pDNzITJ8y
# 5  Joji                  3MZsBdqDrRTJihTHQrO6Dq
# 6  Jungle Giants         6wFwvxJkurQPU2UdeD4qVt
# 7  Magic City Hippies    1ikg4sypcURm8Vy5GP68xb
# 8  Sudan Archives        2MPHBxznH1fj59jbOWY38u
#
#                                                                                                genre  \
# 0  [hardcore punk]
# 1  [electropop, indie poptimism, indie soul, modern alternative rock, modern rock, vapor soul]
# 2  [british jazz]
# 3  [indie pop, indie poptimism, indie rock, minneapolis indie, modern alternative rock, modern rock]
# 4  []
# 5  [alternative r&b, viral pop]
# 6  [australian indie, australian pop]
# 7  [indie pop, indie poptimism, indie rock, miami indie, modern rock, vapor soul]
# 8  [afrofuturism, alternative r&b, art pop, escape room, indie soul, la pop]
#
#                                                     top_locales  listeners  \
# 0  [ Los Angeles,  Chicago,  London,  New York City,  Dallas]    181902
# 1  [ Los Angeles,  Chicago,  Denver,  Dallas,  Sydney]           2073158
# 2  [ London,  Amsterdam,  Berlin,  Paris,  Santiago]             36033
# 3  [ Chicago,  Los Angeles,  Atlanta,  Dallas,  New York City]   2623115
# 4  [ New Orleans,  Houston,  Dallas,  Denver,  College Station]  24
# 5  [ Chicago,  Los Angeles,  Jakarta,  Sydney,  Dallas]          18002479
# 6  [ Sydney,  Brisbane,  Melbourne,  Perth,  Adelaide]           1317064
# 7  [ Chicago,  Los Angeles,  Denver,  Dallas,  Atlanta]          535810
# 8  [ London,  Los Angeles,  Berlin,  Chicago,  Brooklyn]         411646
#
#    followers
# 0  100673
# 1  146423
# 2  13879
# 3  401701
# 4  100
# 5  3425911
# 6  181181
# 7  80353
# 8  113337
